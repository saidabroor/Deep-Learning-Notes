# %%
Whenever we talk about loss function, we take every single data point, we do forward and backward propagation

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Loss function - One input --> One output --> One loss
Cost function - Many inputs --> Many outputs --> Take average --> Thats the cost
