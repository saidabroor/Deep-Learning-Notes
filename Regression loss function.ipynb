# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# RMSE - same as MSE but gives error in original units (easier to interpret)
#
# Penalizes larger error more.
#
# Still sensitive to outliers.

# %%
Huber Loss

Small errors? --> Behave like MSE
Large errors? --> Behave like MAE

Cons:
Needs tuning parameter

# %% [markdown]
# ![image.png](attachment:image.png)
