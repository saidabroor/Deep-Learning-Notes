# %%
ELU, Leaky ReLU and PReLU all solve problems of ReLU but ELU has more advantages than those two.

Advantages:
- no dead relu issues
- zero centered


disadvatages:
 - computationally intensive

# %% [markdown]
# ![image.png](attachment:image.png)
