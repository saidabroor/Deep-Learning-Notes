# %%
Softmax activation function is used in the output layer for multiclass classification problem.
  

Softmax takes a list of numbers and "softly" highlights the biggest one — but still gives small scores to the others too. The bigger the number, the higher the probability.

if model outputs are 2.0, 1.0, 0.1 it turns it into something like 0.65, 0.25, 0.10.

# %% [markdown]
# ![image.png](attachment:image.png)
